# %% [markdown]
# <a href="https://colab.research.google.com/github/4lfman/TorskPopulation/blob/main/TorskPopulation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import random as rn
import matplotlib.pyplot as plt


#plt.style.use('seaborn-white')
#plt.style.use('fivethirtyeight')
plt.style.use('seaborn-whitegrid')
# Out:
# <ipython-input-22-0f826f3594d6>:8: MatplotlibDeprecationWarning: The seaborn styles shipped by Matplotlib are deprecated since 3.6, as they no longer correspond to the styles shipped by seaborn. However, they will remain available as 'seaborn-v0_8-<style>'. Alternatively, directly use the seaborn API instead.
#   plt.style.use('seaborn-whitegrid')

# %%
k = 10
f1 = 100
f2 = 0.4
N0 = 7000
N = 100000
m = 10000
F1 = lambda N: (k+1)*N**1.5
F2 = lambda N: (k+1)*N - f1
F3 = lambda N: (k+1)*N - f2*N
F4 = lambda N: N + k*(1-N/m)
F= lambda N: k * N - f*(0.1*N0-N)

# %%
y = range(12*60)

#def asdfasdf(N,m):
#  xs = []
#  N=N0 
#  for t in y:
#      xs.append(N)
      
#      N = N * (1-rn.uniform(0, 0.8*(N/m)))

      
#  return xs

def undreGräns1(N):
  if(N<1000):
    return 1
  
  return 0.7

def överfiske(N,m):
  xs = []
  N=N0 
  leka = 1
  for t in y:
      xs.append(N)
      
      r = rn.uniform(0,1)
      if r > 0.8:
        N = N / (1+N/m)**(rn.uniform(0, 0.5))
      elif r > undreGräns1(N):
         N = N * (2-N/m)**((rn.uniform(0, 1)))
      else:
        N = N * (1+rn.uniform(-0.05, 0.05))      
  return xs


def undreGräns2(N):
  if(N<1000):
    return 1
  
  return 0.8

def medelfiske(N,m):
  xs = []
  N=N0 
  leka = 1
  for t in y:
      xs.append(N)
      
      r = rn.uniform(0,1)
      if r > 0.9:
        N = N / (1+N/m)**(rn.uniform(0, 0.5))
      elif r > undreGräns2(N):
         N = N * (2-N/m)**((rn.uniform(0.5, 1)))
      else:
        N = N * (1+rn.uniform(-0.05, 0.05))      
  return xs

def undreGräns3(N):
  if(N<1000):
    return 1
  
  return 0.96

def underfiske(N,m):
  xs = []
  N=N0 
  leka = 1
  for t in y:
      xs.append(N)
      
      r = rn.uniform(0,1)
      if r > 0.98:
        N = N / (1+N/m)**(rn.uniform(0, 0.5))
      elif r > undreGräns3(N):
         N = N * (2-N/m)**((rn.uniform(0.5, 1)))
      else:
        N = N * (1+rn.uniform(-0.05, 0.05))      
  return xs



plt.figure(figsize=(12,3))
plt.ylim(0,12000)
plt.plot(y, överfiske(N,m), alpha=1)
for i in range(0, 100):
  plt.plot(y, överfiske(N,m), alpha=.05)



plt.grid()
plt.show()

# %%
xs
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-33-6ac47325ab89> in <module>
# ----> 1 xs
#
# NameError: name 'xs' is not defined
